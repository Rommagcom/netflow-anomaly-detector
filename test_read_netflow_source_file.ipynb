# %%
import netflow
with open("nfcapd.202407031520",'rb') as f:
    bytes_read = f.read()
bytes_read
#p = netflow.parse_packet(bytes_read)  # see test_netflow.py

#assert p.header.version == 5  # NetFlow v5 packet
#assert p.flows[0].PROTO == 1  # ICMP flow
# Out:
# b'\x0c\xa5\x02\x00\x00\x02\x07\xf1a\xa4\x85f\x00\x00\x00\x00\x00\x00\x01\x00\x01\x00\x00\x00J\xa0\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\xe1\x02\x00\x00\x16\xa0\x01\x00\x03\x00\x00\x00\x07\x00 \x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x03h\n\x00\x00\x00\x00\x02\x00\x01\x00\x01\x00\x00\x00\x0f\x00\x18\x00\x01\x00\x01\x00\xff\xff\xff\xff\xff\xff\xff\xff\x01\x00\x00\x00\x00\x00\x00\x00\x0b\x00\x91\x00\x06\x00\x00\x01\x01\x00\x02\t\x01\x004\x00\x86\xee\x06z\x90\x01\x00\x00\x92\xf1\x06z\x90\x01\x00\x00\x15`\nz\x90\x01\x00\x00#\x00\x00\x00\x00\x00\x00\x00\xa3\x8e\x00\x00\x00\x00\x00\x00\xbb\x01:C\x06\x00@\x00\x05\x00\x1c\x00\x01\x00\x00\x00\x00\x00\x00\x00#\x00\x00\x00\x00\x00\x00\x00\xa3\x8e\x00\x00\x00\x00\x00\x00\x04\x00\x14\x00\x19\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x1b\x00\r\x00\x14\x00\x000D\x00\x00\x00\x00\x02\x00\x0c\x00\t\xf9h\n\x01\xf9h\n\x0c\x00\x08\x00\x01\x03h\n\x0b\x00\x91\x00\x06\x00\x00\x01\x01\x00\x02\t\x01\x004\x00\x8
# ...
